# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter
import os
import shutil
import random

def calculate_font_size(text, font_path, max_height, initial_size=20):
    current_size = initial_size
    font = ImageFont.truetype(font_path, current_size)
    
    while ImageDraw.Draw(Image.new('RGB', (1, 1))).multiline_textbbox((0, 0), text, font=font)[3] < 0.9 * max_height:
        current_size += 1
        font = ImageFont.truetype(font_path, current_size)
    
    return current_size

def generate_images_and_labels_from_file(text_file_path, image_height, output_folder, output_labels_file, custom_font=None, random_background=False, random_blur=False, use_all_text=False):
    font_options = [
        {'name': 'Khmer OS Muol Light Regular', 'file': './font/Khmer OS Muol Light Regular.ttf'},
        {'name': 'Khmer OS Battambang Regular', 'file': './font/Khmer OS Battambang Regular.ttf'}
    ]

    if custom_font is not None:
        font_options.append(custom_font)

    # Remove existing output folder
    if os.path.exists(output_folder):
        shutil.rmtree(output_folder)

    # Create output folder
    os.makedirs(output_folder, exist_ok=True)

    # Clear the content of the labels file
    open(output_labels_file, 'w', encoding='utf-8').close()

    with open(output_labels_file, 'a', encoding='utf-8') as labels_file:
        counter = 1

        text_list = []
        if use_all_text:
            with open(text_file_path, 'r', encoding='utf-8') as text_file:
                text_list = text_file.readlines()
            random.shuffle(text_list)
        else:
            text_list.append(open(text_file_path, 'r', encoding='utf-8').readline().strip())

        for text in text_list:
            text = text.strip()
            for font_option in font_options:
                font_size = calculate_font_size(text, font_option['file'], image_height)
                font = ImageFont.truetype(font_option['file'], font_size)

                img = Image.new("RGB", (100, image_height), "white")  # Width doesn't matter initially
                d1 = ImageDraw.Draw(img)

                text_bbox = d1.textbbox((0, 0), text, font=font)
                image_width = text_bbox[2] - text_bbox[0] + 20  # Add some padding
                img = img.resize((image_width, image_height))

                d1 = ImageDraw.Draw(img)
                text_position = ((image_width - text_bbox[2]) // 2, (image_height - text_bbox[3]) // 2)
                text_color = "black"

                d1.text(text_position, text, fill=text_color, font=font)

                # Random background color
                if random_background:
                    background_color = random.choice(["black", "gray", "white"])
                    img = Image.new("RGB", (image_width, image_height), background_color)
                    d1 = ImageDraw.Draw(img)
                    d1.text(text_position, text, fill=text_color, font=font)

                # Random blur
                if random_blur:
                    blur_radius = random.randint(0, 5)
                    img = img.filter(ImageFilter.GaussianBlur(radius=blur_radius))

                # Use a simple image name with a counter
                image_name = f"{counter}.jpg"
                output_path = os.path.join(output_folder, image_name)
                img.save(output_path)

                # Remove the './dataset' prefix from image paths
                rel_image_path = os.path.relpath(output_path, start='./dataset')
                # Write label to the labels file in real-time
                labels_file.write(f"{rel_image_path} {text}\n")

                print('Generate image:', rel_image_path + ' | ' + text)
                counter += 1

    print(f"Images exported to: {output_folder}")
    print(f"Labels exported to: {output_labels_file}")

def main():
    image_height = 128
    output_folder = 'output/'
    output_labels_file = 'labels.txt'
    text_file_path = "dict.txt"  # Change this to your text file path

    generate_images_and_labels_from_file(text_file_path, image_height, output_folder, output_labels_file, random_background=True, random_blur=True, use_all_text=True)

if __name__ == "__main__":
    main()
# Out:
# Generate image: ../output/1.jpg | មិនអាច
# Generate image: ../output/2.jpg | មិនអាច
# Generate image: ../output/3.jpg | ក្បាល
# Generate image: ../output/4.jpg | ក្បាល
# Generate image: ../output/5.jpg | ប្រអប់
# Generate image: ../output/6.jpg | ប្រអប់
# Generate image: ../output/7.jpg | កម្រើក
# Generate image: ../output/8.jpg | កម្រើក
# Generate image: ../output/9.jpg | ជើង
# Generate image: ../output/10.jpg | ជើង
# Generate image: ../output/11.jpg | ត
# Generate image: ../output/12.jpg | ត
# Generate image: ../output/13.jpg | មានរបស់គរ
# Generate image: ../output/14.jpg | មានរបស់គរ
# Generate image: ../output/15.jpg | ណែន
# Generate image: ../output/16.jpg | ណែន
# Generate image: ../output/17.jpg | ប្រអប់
# Generate image: ../output/18.jpg | ប្រអប់
# Generate image: ../output/19.jpg | ងាក
# Generate image: ../output/20.jpg | ងាក
# Generate image: ../output/21.jpg | ឬជើង
# Generate image: ../output/22.jpg | ឬជើង
# Generate image: ../output/23.jpg | អវយវៈ
# Generate image: ../output/24.jpg | អវយវៈ
# Generate image: ../output/25.jpg | សត្វ
# Generate image: ../output/26.jpg | សត្វ
# Generate image: ../output/27.jpg | ឬធ្វើចលនាបាន
# Generate image: ../output/28.jpg | ឬធ្វើចលនាបាន
# Generate image: ../output/29.jpg | ពី
# Generate image: ../output/30.jpg | ពី
# Generate image: ../output/31.jpg | ដែលត
# Generate image: ../output/32.jpg | ដែលត
# Generate image: ../output/33.jpg | តាប់
# Generate image: ../output/34.jpg | តាប់
# Generate image: ../output/35.jpg | កំភួន
# Generate image: ../output/36.jpg | កំភួន
# Generate image: ../output/37.jpg | រំកិល
# Generate image: ../output/38.jpg | រំកិល
# Generate image: ../output/39.jpg | ដោយសារ
# Generate image: ../output/40.jpg | ដោយសារ
# Generate image: ../output/41.jpg | ពី
# Generate image: ../output/42.jpg | ពី
# Generate image: ../output/43.jpg | ដៃទៅ
# Generate image: ../output/44.jpg | ដៃទៅ
# Generate image: ../output/45.jpg | គ្នាឬមនុស្សច្រើន
# Generate image: ../output/46.jpg | គ្នាឬមនុស្សច្រើន
# Generate image: ../output/47.jpg | នៃមនុស្ស
# Generate image: ../output/48.jpg | នៃមនុស្ស
# Generate image: ../output/49.jpg | ទៅ
# Generate image: ../output/50.jpg | ទៅ
# Generate image: ../output/51.jpg | តាន់
# Generate image: ../output/52.jpg | តាន់
# Generate image: ../output/53.jpg | ដៃឬ
# Generate image: ../output/54.jpg | ដៃឬ
# Generate image: ../output/55.jpg | ភ្ជាប់ពី
# Generate image: ../output/56.jpg | ភ្ជាប់ពី
# Generate image: ../output/57.jpg | ផ្នែក
# Generate image: ../output/58.jpg | ផ្នែក
# Generate image: ../output/59.jpg | ផ្លាស់ទី
# Generate image: ../output/60.jpg | ផ្លាស់ទី
# Generate image: ../output/61.jpg | ណាន់
# Generate image: ../output/62.jpg | ណាន់
# Generate image: ../output/63.jpg | កំភួនជើង
# Generate image: ../output/64.jpg | កំភួនជើង
# Generate image: ../output/65.jpg | ទៅស្មាឬទៅខ្លួន
# Generate image: ../output/66.jpg | ទៅស្មាឬទៅខ្លួន
# Generate image: ../output/67.jpg | នៃដៃ
# Generate image: ../output/68.jpg | នៃដៃ
# Generate image: ../output/69.jpg | ដែល
# Generate image: ../output/70.jpg | ដែល
# Generate image: ../output/71.jpg | ជាប់បន្ត
# Generate image: ../output/72.jpg | ជាប់បន្ត
# Images exported to: output/
# Labels exported to: labels.txt

# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter
import os
import random
import shutil

def calculate_font_size(text, font_path, max_height, initial_size=20):
    current_size = initial_size
    font = ImageFont.truetype(font_path, current_size)
    
    while ImageDraw.Draw(Image.new('RGB', (1, 1))).multiline_textbbox((0, 0), text, font=font)[3] < 0.9 * max_height:
        current_size += 1
        font = ImageFont.truetype(font_path, current_size)
    
    return current_size

def generate_images_and_labels_from_file(file_path, image_height, output_folder, output_labels_file, random_blur=False, font_path=None):
    font_options = [
        {'name': 'Khmer OS Muol Light Regular', 'file': './font/Khmer OS Muol Light Regular.ttf'},
        {'name': 'Khmer OS Battambang Regular', 'file': './font/Khmer OS Battambang Regular.ttf'}
    ]

    # Remove existing output folder
    if os.path.exists(output_folder):
        shutil.rmtree(output_folder)

    # Create output folder
    os.makedirs(output_folder, exist_ok=True)

    # Clear the content of the labels file
    open(output_labels_file, 'w', encoding='utf-8').close()

    with open(output_labels_file, 'a', encoding='utf-8') as labels_file:
        counter = 1
        text_list = open(file_path, 'r', encoding='utf-8').readlines()

        for text in text_list:
            text = text.strip()
            for font_option in font_options:
                font_size = calculate_font_size(text, font_option['file'], image_height)
                font = ImageFont.truetype(font_option['file'], font_size)

                img = Image.new("RGB", (100, image_height), "white")  # Width doesn't matter initially
                d1 = ImageDraw.Draw(img)

                text_bbox = d1.textbbox((0, 0), text, font=font)
                image_width = text_bbox[2] - text_bbox[0] + 20  # Add some padding
                img = img.resize((image_width, image_height))

                d1 = ImageDraw.Draw(img)
                text_position = ((image_width - text_bbox[2]) // 2, (image_height - text_bbox[3]) // 2)
                
                text_color = "black"

                d1.text(text_position, text, fill=text_color, font=font)

                # Random blur
                if random_blur:
                    blur_radius = random.randint(0, 5)
                    img = img.filter(ImageFilter.GaussianBlur(radius=blur_radius))

                # Use a simple image name with a counter
                image_name = f"{counter}.jpg"
                output_path = os.path.join(output_folder, image_name)
                img.save(output_path)

                # Write label to the labels file in real-time
                # Remove the 'output/' prefix from the output path
                output_path = output_path.replace('output/', '')
                labels_file.write(f"{output_path} {text}\n")

                print('Generate image:', output_path + ' | ' + text)
                counter += 1

def main():
    image_height = 128
    output_folder = 'output'
    output_labels_file = 'labels.txt'
    text_file_path = "dict.txt"  # Change this to your text file path

    generate_images_and_labels_from_file(text_file_path, image_height, output_folder, output_labels_file, random_blur=True)

if __name__ == "__main__":
    main()
# Out:
# Generate image: 1.jpg | អវយវៈ
# Generate image: 2.jpg | អវយវៈ
# Generate image: 3.jpg | ដែល
# Generate image: 4.jpg | ដែល
# Generate image: 5.jpg | ត
# Generate image: 6.jpg | ត
# Generate image: 7.jpg | ពី
# Generate image: 8.jpg | ពី
# Generate image: 9.jpg | ក្បាល
# Generate image: 10.jpg | ក្បាល
# Generate image: 11.jpg | ទៅស្មាឬទៅខ្លួន
# Generate image: 12.jpg | ទៅស្មាឬទៅខ្លួន
# Generate image: 13.jpg | នៃមនុស្ស
# Generate image: 14.jpg | នៃមនុស្ស
# Generate image: 15.jpg | សត្វ
# Generate image: 16.jpg | សត្វ
# Generate image: 17.jpg | ផ្នែក
# Generate image: 18.jpg | ផ្នែក
# Generate image: 19.jpg | នៃដៃ
# Generate image: 20.jpg | នៃដៃ
# Generate image: 21.jpg | ឬជើង
# Generate image: 22.jpg | ឬជើង
# Generate image: 23.jpg | ដែលត
# Generate image: 24.jpg | ដែលត
# Generate image: 25.jpg | ភ្ជាប់ពី
# Generate image: 26.jpg | ភ្ជាប់ពី
# Generate image: 27.jpg | ប្រអប់
# Generate image: 28.jpg | ប្រអប់
# Generate image: 29.jpg | ដៃទៅ
# Generate image: 30.jpg | ដៃទៅ
# Generate image: 31.jpg | កំភួន
# Generate image: 32.jpg | កំភួន
# Generate image: 33.jpg | ដៃឬ
# Generate image: 34.jpg | ដៃឬ
# Generate image: 35.jpg | ពី
# Generate image: 36.jpg | ពី
# Generate image: 37.jpg | ប្រអប់
# Generate image: 38.jpg | ប្រអប់
# Generate image: 39.jpg | ជើង
# Generate image: 40.jpg | ជើង
# Generate image: 41.jpg | ទៅ
# Generate image: 42.jpg | ទៅ
# Generate image: 43.jpg | កំភួនជើង
# Generate image: 44.jpg | កំភួនជើង
# Generate image: 45.jpg | មិនអាច
# Generate image: 46.jpg | មិនអាច
# Generate image: 47.jpg | ផ្លាស់ទី
# Generate image: 48.jpg | ផ្លាស់ទី
# Generate image: 49.jpg | រំកិល
# Generate image: 50.jpg | រំកិល
# Generate image: 51.jpg | ងាក
# Generate image: 52.jpg | ងាក
# Generate image: 53.jpg | កម្រើក
# Generate image: 54.jpg | កម្រើក
# Generate image: 55.jpg | ឬធ្វើចលនាបាន
# Generate image: 56.jpg | ឬធ្វើចលនាបាន
# Generate image: 57.jpg | ដោយសារ
# Generate image: 58.jpg | ដោយសារ
# Generate image: 59.jpg | មានរបស់គរ
# Generate image: 60.jpg | មានរបស់គរ
# Generate image: 61.jpg | ជាប់បន្ត
# Generate image: 62.jpg | ជាប់បន្ត
# Generate image: 63.jpg | គ្នាឬមនុស្សច្រើន
# Generate image: 64.jpg | គ្នាឬមនុស្សច្រើន
# Generate image: 65.jpg | ណែន
# Generate image: 66.jpg | ណែន
# Generate image: 67.jpg | ណាន់
# Generate image: 68.jpg | ណាន់
# Generate image: 69.jpg | តាន់
# Generate image: 70.jpg | តាន់
# Generate image: 71.jpg | តាប់
# Generate image: 72.jpg | តាប់

# %%
from PIL import Image, ImageDraw, ImageFont, ImageFilter
import os
import random
import shutil

def calculate_font_size(text, font_path, max_height, initial_size=20):
    current_size = initial_size
    font = ImageFont.truetype(font_path, current_size)
    
    while ImageDraw.Draw(Image.new('RGB', (1, 1))).multiline_textbbox((0, 0), text, font=font)[3] < 0.9 * max_height:
        current_size += 1
        font = ImageFont.truetype(font_path, current_size)
    
    return current_size

def generate_images_and_labels_from_file(file_path, image_height, output_folder, output_labels_file, font_option=[], random_blur=False):
    font_options = [
        {'name': 'AKbalthom KhmerLer Regular', 'file': './font/AKbalthom KhmerLer Regular.ttf'},
        {'name': 'Khmer MEF1 Regular', 'file': './font/Khmer MEF1 Regular.ttf'},
        {'name': 'Khmer OS Battambang Regular', 'file': './font/Khmer OS Battambang Regular.ttf'},
        {'name': 'Khmer OS Muol Light Regular', 'file': './font/Khmer OS Muol Light Regular.ttf'},
        {'name': 'Khmer OS Siemreap Regular', 'file': './font/Khmer OS Siemreap Regular.ttf'},
    ]
    
    if not font_option:
        selected_fonts = font_options
    else:
        selected_fonts = [font_options[i - 1] for i in font_option]

    # Remove existing output folder
    if os.path.exists(output_folder):
        shutil.rmtree(output_folder)

    # Create output folder
    os.makedirs(output_folder, exist_ok=True)

    # Clear the content of the labels file
    open(output_labels_file, 'w', encoding='utf-8').close()

    with open(output_labels_file, 'a', encoding='utf-8') as labels_file:
        counter = 1
        text_list = open(file_path, 'r', encoding='utf-8').readlines()

        for text in text_list:
            text = text.strip()
            for font_option in selected_fonts:
                font_size = calculate_font_size(text, font_option['file'], image_height)
                font = ImageFont.truetype(font_option['file'], font_size)

                img = Image.new("RGB", (100, image_height), "white")  # Width doesn't matter initially
                d1 = ImageDraw.Draw(img)

                text_bbox = d1.textbbox((0, 0), text, font=font)
                image_width = text_bbox[2] - text_bbox[0] + 20  # Add some padding
                img = img.resize((image_width, image_height))

                d1 = ImageDraw.Draw(img)
                text_position = ((image_width - text_bbox[2]) // 2, (image_height - text_bbox[3]) // 2)
                
                text_color = "black"

                d1.text(text_position, text, fill=text_color, font=font)

                # Random blur
                if random_blur:
                    blur_radius = random.randint(0, 5)
                    img = img.filter(ImageFilter.GaussianBlur(radius=blur_radius))

                # Use a simple image name with a counter
                image_name = f"{counter}.jpg"
                output_path = os.path.join(output_folder, image_name)
                img.save(output_path)

                # Write label to the labels file in real-time
                # Remove the 'output/' prefix from the output path
                output_path = output_path.replace('output/', '')
                labels_file.write(f"{output_path} {text}\n")

                print('Generate image:', output_path + ' | ' + text)
                counter += 1

def main():
    image_height = 128
    output_folder = 'output'
    output_labels_file = 'labels.txt'
    text_file_path = "dict.txt"  # Change this to your text file path
    font_option = []  # Select font options here, e.g., [1] for Khmer OS Muol Light Regular, [2] for Khmer OS Battambang Regular, or [] for all fonts

    generate_images_and_labels_from_file(text_file_path, image_height, output_folder, output_labels_file, font_option=font_option, random_blur=True)

if __name__ == "__main__":
    main()
# Out:
# Generate image: 1.jpg | អវយវៈ
# Generate image: 2.jpg | អវយវៈ
# Generate image: 3.jpg | អវយវៈ
# Generate image: 4.jpg | អវយវៈ
# Generate image: 5.jpg | អវយវៈ
# Generate image: 6.jpg | ដែល
# Generate image: 7.jpg | ដែល
# Generate image: 8.jpg | ដែល
# Generate image: 9.jpg | ដែល
# Generate image: 10.jpg | ដែល
# Generate image: 11.jpg | ត
# Generate image: 12.jpg | ត
# Generate image: 13.jpg | ត
# Generate image: 14.jpg | ត
# Generate image: 15.jpg | ត
# Generate image: 16.jpg | ពី
# Generate image: 17.jpg | ពី
# Generate image: 18.jpg | ពី
# Generate image: 19.jpg | ពី
# Generate image: 20.jpg | ពី
# Generate image: 21.jpg | ក្បាល
# Generate image: 22.jpg | ក្បាល
# Generate image: 23.jpg | ក្បាល
# Generate image: 24.jpg | ក្បាល
# Generate image: 25.jpg | ក្បាល
# Generate image: 26.jpg | ទៅស្មាឬទៅខ្លួន
# Generate image: 27.jpg | ទៅស្មាឬទៅខ្លួន
# Generate image: 28.jpg | ទៅស្មាឬទៅខ្លួន
# Generate image: 29.jpg | ទៅស្មាឬទៅខ្លួន
# Generate image: 30.jpg | ទៅស្មាឬទៅខ្លួន
# Generate image: 31.jpg | នៃមនុស្ស
# Generate image: 32.jpg | នៃមនុស្ស
# Generate image: 33.jpg | នៃមនុស្ស
# Generate image: 34.jpg | នៃមនុស្ស
# Generate image: 35.jpg | នៃមនុស្ស
# Generate image: 36.jpg | សត្វ
# Generate image: 37.jpg | សត្វ
# Generate image: 38.jpg | សត្វ
# Generate image: 39.jpg | សត្វ
# Generate image: 40.jpg | សត្វ
# Generate image: 41.jpg | ផ្នែក
# Generate image: 42.jpg | ផ្នែក
# Generate image: 43.jpg | ផ្នែក
# Generate image: 44.jpg | ផ្នែក
# Generate image: 45.jpg | ផ្នែក
# Generate image: 46.jpg | នៃដៃ
# Generate image: 47.jpg | នៃដៃ
# Generate image: 48.jpg | នៃដៃ
# Generate image: 49.jpg | នៃដៃ
# Generate image: 50.jpg | នៃដៃ
# Generate image: 51.jpg | ឬជើង
# Generate image: 52.jpg | ឬជើង
# Generate image: 53.jpg | ឬជើង
# Generate image: 54.jpg | ឬជើង
# Generate image: 55.jpg | ឬជើង
# Generate image: 56.jpg | ដែលត
# Generate image: 57.jpg | ដែលត
# Generate image: 58.jpg | ដែលត
# Generate image: 59.jpg | ដែលត
# Generate image: 60.jpg | ដែលត
# Generate image: 61.jpg | ភ្ជាប់ពី
# Generate image: 62.jpg | ភ្ជាប់ពី
# Generate image: 63.jpg | ភ្ជាប់ពី
# Generate image: 64.jpg | ភ្ជាប់ពី
# Generate image: 65.jpg | ភ្ជាប់ពី
# Generate image: 66.jpg | ប្រអប់
# Generate image: 67.jpg | ប្រអប់
# Generate image: 68.jpg | ប្រអប់
# Generate image: 69.jpg | ប្រអប់
# Generate image: 70.jpg | ប្រអប់
# Generate image: 71.jpg | ដៃទៅ
# Generate image: 72.jpg | ដៃទៅ
# Generate image: 73.jpg | ដៃទៅ
# Generate image: 74.jpg | ដៃទៅ
# Generate image: 75.jpg | ដៃទៅ
# Generate image: 76.jpg | កំភួន
# Generate image: 77.jpg | កំភួន
# Generate image: 78.jpg | កំភួន
# Generate image: 79.jpg | កំភួន
# Generate image: 80.jpg | កំភួន
# Generate image: 81.jpg | ដៃឬ
# Generate image: 82.jpg | ដៃឬ
# Generate image: 83.jpg | ដៃឬ
# Generate image: 84.jpg | ដៃឬ
# Generate image: 85.jpg | ដៃឬ
# Generate image: 86.jpg | ពី
# Generate image: 87.jpg | ពី
# Generate image: 88.jpg | ពី
# Generate image: 89.jpg | ពី
# Generate image: 90.jpg | ពី
# Generate image: 91.jpg | ប្រអប់
# Generate image: 92.jpg | ប្រអប់
# Generate image: 93.jpg | ប្រអប់
# Generate image: 94.jpg | ប្រអប់
# Generate image: 95.jpg | ប្រអប់
# Generate image: 96.jpg | ជើង
# Generate image: 97.jpg | ជើង
# Generate image: 98.jpg | ជើង
# Generate image: 99.jpg | ជើង
# Generate image: 100.jpg | ជើង
# Generate image: 101.jpg | ទៅ
# Generate image: 102.jpg | ទៅ
# Generate image: 103.jpg | ទៅ
# Generate image: 104.jpg | ទៅ
# Generate image: 105.jpg | ទៅ
# Generate image: 106.jpg | កំភួនជើង
# Generate image: 107.jpg | កំភួនជើង
# Generate image: 108.jpg | កំភួនជើង
# Generate image: 109.jpg | កំភួនជើង
# Generate image: 110.jpg | កំភួនជើង
# Generate image: 111.jpg | មិនអាច
# Generate image: 112.jpg | មិនអាច
# Generate image: 113.jpg | មិនអាច
# Generate image: 114.jpg | មិនអាច
# Generate image: 115.jpg | មិនអាច
# Generate image: 116.jpg | ផ្លាស់ទី
# Generate image: 117.jpg | ផ្លាស់ទី
# Generate image: 118.jpg | ផ្លាស់ទី
# Generate image: 119.jpg | ផ្លាស់ទី
# Generate image: 120.jpg | ផ្លាស់ទី
# Generate image: 121.jpg | រំកិល
# Generate image: 122.jpg | រំកិល
# Generate image: 123.jpg | រំកិល
# Generate image: 124.jpg | រំកិល
# Generate image: 125.jpg | រំកិល
# Generate image: 126.jpg | ងាក
# Generate image: 127.jpg | ងាក
# Generate image: 128.jpg | ងាក
# Generate image: 129.jpg | ងាក
# Generate image: 130.jpg | ងាក
# Generate image: 131.jpg | កម្រើក
# Generate image: 132.jpg | កម្រើក
# Generate image: 133.jpg | កម្រើក
# Generate image: 134.jpg | កម្រើក
# Generate image: 135.jpg | កម្រើក
# Generate image: 136.jpg | ឬធ្វើចលនាបាន
# Generate image: 137.jpg | ឬធ្វើចលនាបាន
# Generate image: 138.jpg | ឬធ្វើចលនាបាន
# Generate image: 139.jpg | ឬធ្វើចលនាបាន
# Generate image: 140.jpg | ឬធ្វើចលនាបាន
# Generate image: 141.jpg | ដោយសារ
# Generate image: 142.jpg | ដោយសារ
# Generate image: 143.jpg | ដោយសារ
# Generate image: 144.jpg | ដោយសារ
# Generate image: 145.jpg | ដោយសារ
# Generate image: 146.jpg | មានរបស់គរ
# Generate image: 147.jpg | មានរបស់គរ
# Generate image: 148.jpg | មានរបស់គរ
# Generate image: 149.jpg | មានរបស់គរ
# Generate image: 150.jpg | មានរបស់គរ
# Generate image: 151.jpg | ជាប់បន្ត
# Generate image: 152.jpg | ជាប់បន្ត
# Generate image: 153.jpg | ជាប់បន្ត
# Generate image: 154.jpg | ជាប់បន្ត
# Generate image: 155.jpg | ជាប់បន្ត
# Generate image: 156.jpg | គ្នាឬមនុស្សច្រើន
# Generate image: 157.jpg | គ្នាឬមនុស្សច្រើន
# Generate image: 158.jpg | គ្នាឬមនុស្សច្រើន
# Generate image: 159.jpg | គ្នាឬមនុស្សច្រើន
# Generate image: 160.jpg | គ្នាឬមនុស្សច្រើន
# Generate image: 161.jpg | ណែន
# Generate image: 162.jpg | ណែន
# Generate image: 163.jpg | ណែន
# Generate image: 164.jpg | ណែន
# Generate image: 165.jpg | ណែន
# Generate image: 166.jpg | ណាន់
# Generate image: 167.jpg | ណាន់
# Generate image: 168.jpg | ណាន់
# Generate image: 169.jpg | ណាន់
# Generate image: 170.jpg | ណាន់
# Generate image: 171.jpg | តាន់
# Generate image: 172.jpg | តាន់
# Generate image: 173.jpg | តាន់
# Generate image: 174.jpg | តាន់
# Generate image: 175.jpg | តាន់
# Generate image: 176.jpg | តាប់
# Generate image: 177.jpg | តាប់
# Generate image: 178.jpg | តាប់
# Generate image: 179.jpg | តាប់
# Generate image: 180.jpg | តាប់
